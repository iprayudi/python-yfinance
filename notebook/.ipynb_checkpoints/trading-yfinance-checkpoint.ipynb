# %% [markdown]
# ## Importing libraries

# %%
# To create datetime objects 
import datetime
from datetime import date, timedelta

# To grab stock data
import yfinance as fyf

# %matplotlib inline
import matplotlib.pyplot as plt

from pandas_datareader import data as pdr
fyf.pdr_override() # <-- Here is the fix

# %% [markdown]
# ## Pull stock data

# %%
# Set label
stocks = [ # If you want to grab multiple stocks add more labels to this list
    "ICBP.JK", 
    "SIDO.JK",
    "MYOR.JK",
    "UNVR.JK",
    "INDF.JK",
    "ULTJ.JK"
] 

##
## Set start and end dates
##

start = datetime.datetime(2020, 1, 1)
end   = datetime.datetime(2020, 10, 10)
# start = date.today()-timedelta(5)
# end   = date.today()

# Grab data
df = pdr.get_data_yahoo(stocks, start = start, end = end)
print("DataFrame shape: "+str(df.shape))
df
# Out:
# [*********************100%***********************]  6 of 6 completed
# DataFrame shape: (190, 36)
#                Adj Close                                                     \
#                  ICBP.JK      INDF.JK      MYOR.JK     SIDO.JK      ULTJ.JK
# Date
# 2020-01-02  10894.973633  7645.327148  2002.933350  615.705872  1638.845093
# 2020-01-03  10992.686523  7693.260254  2002.933350  615.705872  1599.115479
# 2020-01-06  11236.967773  7669.293945  1993.066650  620.516052  1564.352173
# 2020-01-07  11236.967773  7861.026367  2002.933350  622.921143  1579.250732
# 2020-01-08  11285.824219  7884.992676  1973.333374  625.326233  1574.284546
# ...                  ...          ...          ...         ...          ...
# 2020-10-05  10100.000000  7100.000000  2440.000000  723.515625  1740.000000
# 2020-10-06  10100.000000  7225.000000  2460.000000  733.359375  1765.000000
# 2020-10-07  10000.000000  7125.000000  2450.000000  733.359375  1765.000000
# 2020-10-08  10075.000000  7225.000000  2450.000000  772.734375  1740.000000
# 2020-10-09  10050.000000  7225.000000  2430.000000  772.734375  1740.000000
#
#                            Close                          ...    Open          \
#                 UNVR.JK  ICBP.JK INDF.JK MYOR.JK SIDO.JK  ... MYOR.JK SIDO.JK
# Date                                                      ...
# 2020-01-02  8438.771484  11150.0  7975.0  2030.0   640.0  ...  2050.0   637.5
# 2020-01-03  8463.446289  11250.0  8025.0  2030.0   640.0  ...  2030.0   640.0
# 2020-01-06  8364.748047  11500.0  8000.0  2020.0   645.0  ...  2030.0   640.0
# 2020-01-07  8340.073242  11500.0  8200.0  2030.0   647.5  ...  2020.0   645.0
# 2020-01-08  8216.699219  11550.0  8225.0  2000.0   650.0  ...  2030.0   650.0
# ...                 ...      ...     ...     ...     ...  ...     ...     ...
# 2020-10-05  8075.000000  10100.0  7100.0  2440.0   735.0  ...  2420.0   740.0
# 2020-10-06  7975.000000  10100.0  7225.0  2460.0   745.0  ...  2450.0   745.0
# 2020-10-07  8000.000000  10000.0  7125.0  2450.0   745.0  ...  2460.0   745.0
# 2020-10-08  8025.000000  10075.0  7225.0  2450.0   785.0  ...  2450.0   750.0
# 2020-10-09  8050.000000  10050.0  7225.0  2430.0   785.0  ...  2450.0   785.0
#
#                              Volume                                       \
#            ULTJ.JK UNVR.JK  ICBP.JK  INDF.JK  MYOR.JK   SIDO.JK  ULTJ.JK
# Date
# 2020-01-02  1670.0  8500.0  1240200  5257300  1547000   3078800   678000
# 2020-01-03  1650.0  8675.0  3044300  7682700  2578900   3688200   441900
# 2020-01-06  1610.0  8575.0  3369400  5142700  1177400  14759200   568900
# 2020-01-07  1580.0  8475.0  4636500  7510200  1406500  12680600   414700
# 2020-01-08  1600.0  8450.0  3602100  7760200  2454400   7201200   325100
# ...            ...     ...      ...      ...      ...       ...      ...
# 2020-10-05  1715.0  8100.0  2439600  2731300  2255500   4848600   334700
# 2020-10-06  1740.0  8100.0  2538900  7241600   994100  14741300  1093300
# 2020-10-07  1765.0  7975.0  4764400  8868400   969200   7314600   601000
# 2020-10-08  1765.0  8000.0  3209400  6069800  1276500  33717500   350900
# 2020-10-09  1740.0  8025.0  2004200  2322100  1146900  13429900   157400
#
#
#              UNVR.JK
# Date
# 2020-01-02  11059800
# 2020-01-03   8071700
# 2020-01-06   7913300
# 2020-01-07   5793000
# 2020-01-08   8261400
# ...              ...
# 2020-10-05   7906400
# 2020-10-06   6818900
# 2020-10-07   7614400
# 2020-10-08   5225600
# 2020-10-09   4652000
#
# [190 rows x 36 columns]
