# %% [markdown]
# ## Importing libraries

# %%
# To create datetime objects 
import datetime
from datetime import date, timedelta
import numpy as np 

# To grab stock data
import yfinance as fyf

# %matplotlib inline
import matplotlib.pyplot as plt

from pandas_datareader import data as pdr
fyf.pdr_override() # <-- Here is the fix

# %% [markdown]
# ## Pull stock data

# %%
# Set label
stocks = [ # If you want to grab multiple stocks add more labels to this list
    "ICBP.JK", 
    "SIDO.JK",
    "MYOR.JK",
    "UNVR.JK",
    "INDF.JK",
    "ULTJ.JK"
] 

##
## Set start and end dates
##

# start = datetime.datetime(2020, 1, 1)
# end   = datetime.datetime(2020, 10, 10)
# start = date.today()-timedelta(10)
end   = date.today()+timedelta(1) # must be D+1 to include today's data

# Grab data
df = pdr.get_data_yahoo(stocks, start = start, end = end)
print("DataFrame shape: "+ str(df.shape))
df
# Out:
# [*********************100%***********************]  6 of 6 completed
# DataFrame shape: (209, 36)
#                Adj Close                                                     \
#                  ICBP.JK      INDF.JK      MYOR.JK     SIDO.JK      ULTJ.JK
# Date
# 2020-01-02  10894.973633  7645.327148  2002.933350  615.705872  1638.845093
# 2020-01-03  10992.686523  7693.260254  2002.933350  615.705872  1599.115479
# 2020-01-06  11236.967773  7669.293945  1993.066650  620.516052  1564.352173
# 2020-01-07  11236.967773  7861.026367  2002.933350  622.921143  1579.250732
# 2020-01-08  11285.824219  7884.992676  1973.333374  625.326233  1574.284546
# ...                  ...          ...          ...         ...          ...
# 2020-11-04   9775.000000  6950.000000  2330.000000  815.000000  1640.000000
# 2020-11-05   9900.000000  7125.000000  2400.000000  815.000000  1645.000000
# 2020-11-06   9875.000000  7175.000000  2400.000000  830.000000  1670.000000
# 2020-11-09   9750.000000  7200.000000  2400.000000  840.000000  1680.000000
# 2020-11-10   9675.000000  7150.000000  2400.000000  845.000000  1680.000000
#
#                            Close                          ...    Open          \
#                 UNVR.JK  ICBP.JK INDF.JK MYOR.JK SIDO.JK  ... MYOR.JK SIDO.JK
# Date                                                      ...
# 2020-01-02  8438.771484  11150.0  7975.0  2030.0   640.0  ...  2050.0   637.5
# 2020-01-03  8463.446289  11250.0  8025.0  2030.0   640.0  ...  2030.0   640.0
# 2020-01-06  8364.748047  11500.0  8000.0  2020.0   645.0  ...  2030.0   640.0
# 2020-01-07  8340.073242  11500.0  8200.0  2030.0   647.5  ...  2020.0   645.0
# 2020-01-08  8216.699219  11550.0  8225.0  2000.0   650.0  ...  2030.0   650.0
# ...                 ...      ...     ...     ...     ...  ...     ...     ...
# 2020-11-04  7800.000000   9775.0  6950.0  2330.0   815.0  ...  2370.0   815.0
# 2020-11-05  7900.000000   9900.0  7125.0  2400.0   815.0  ...  2330.0   815.0
# 2020-11-06  8075.000000   9875.0  7175.0  2400.0   830.0  ...  2420.0   815.0
# 2020-11-09  7950.000000   9750.0  7200.0  2400.0   840.0  ...  2400.0   840.0
# 2020-11-10  7800.000000   9675.0  7150.0  2400.0   845.0  ...  2400.0   840.0
#
#                               Volume                                        \
#            ULTJ.JK UNVR.JK   ICBP.JK   INDF.JK  MYOR.JK   SIDO.JK  ULTJ.JK
# Date
# 2020-01-02  1670.0  8500.0   1240200   5257300  1547000   3078800   678000
# 2020-01-03  1650.0  8675.0   3044300   7682700  2578900   3688200   441900
# 2020-01-06  1610.0  8575.0   3369400   5142700  1177400  14759200   568900
# 2020-01-07  1580.0  8475.0   4636500   7510200  1406500  12680600   414700
# 2020-01-08  1600.0  8450.0   3602100   7760200  2454400   7201200   325100
# ...            ...     ...       ...       ...      ...       ...      ...
# 2020-11-04  1655.0  7850.0   2680800   7124700  3220700  18617400  2417800
# 2020-11-05  1645.0  7950.0   5042500   9670300  3493800   7496100  1558000
# 2020-11-06  1645.0  7900.0  10391600  17154400  9185500  28087500  1168100
# 2020-11-09  1675.0  8075.0   9146900  15842000  4765000  21029100   945300
# 2020-11-10  1725.0  8050.0  21280100  16395800  4202800  23042600  1922800
#
#
#              UNVR.JK
# Date
# 2020-01-02  11059800
# 2020-01-03   8071700
# 2020-01-06   7913300
# 2020-01-07   5793000
# 2020-01-08   8261400
# ...              ...
# 2020-11-04   6185300
# 2020-11-05   9875000
# 2020-11-06  18386900
# 2020-11-09  15537900
# 2020-11-10  25530300
#
# [209 rows x 36 columns]

# %% [markdown]
# ## Get individual stock data

# %%
i='ICBP.JK' # specify stock's ticker/symbol here
df.loc[:,(slice(None), (i))]
df.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2020-10-23', '2020-10-26', '2020-10-27', '2020-11-02',
#                '2020-11-03', '2020-11-04', '2020-11-05', '2020-11-06',
#                '2020-11-09', '2020-11-10'],
#               dtype='datetime64[ns]', name='Date', length=209, freq=None)

# %% [markdown]
# ## Get latest individual stock data

# %%
i='ICBP.JK' # specify stock's ticker/symbol here
df.iloc[-1][:,i]
# Out:
# Adj Close        9675.0
# Close            9675.0
# High             9850.0
# Low              9650.0
# Open             9775.0
# Volume       21280100.0
# Name: 2020-11-10 00:00:00, dtype: float64

# %% [markdown]
# ## Get spesific stock data

# %%
i='ICBP.JK' # specify stock's ticker/symbol here
price_date = str(datetime.datetime(2020, 11, 2).date()) # specify date here
df.loc[price_date][:,i]

## Close price only
# df.loc[price_date]['Close',i]

## Open price only
# df.loc[price_date]['Open',i]

## HIGH price only
# df.loc[price_date]['High',i]

## LOW price only
# df.loc[price_date]['Low',i]

## Volume only
# df.loc[price_date]['Volume',i]
# Out:
# Adj Close       9750.0
# Close           9750.0
# High            9925.0
# Low             9625.0
# Open            9650.0
# Volume       9102800.0
# Name: 2020-11-02 00:00:00, dtype: float64
